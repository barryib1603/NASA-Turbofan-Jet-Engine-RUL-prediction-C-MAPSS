# %%
'''from google.colab import drive
drive.mount('/content/drive')'''
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')"

# %%
#!pip install catboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy.stats import pearsonr

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
#myfolder = "./"
myfolder = "../data/CMaps/"

# %% [markdown]
# # **Columns' names**

# %%
#Columns' names
'''
1)  unit number
2)	time, in cycles
3)	operational setting 1
4)	operational setting 2
5)	operational setting 3
6)	sensor measurement  1
7)	sensor measurement  2
...
26)	sensor measurement  21
'''
unitNames = ['UnitNumber']
timeCycles = ["TimeInCycles"]
operSets = ["OperSet"+str(i) for i in range(1,4)] # 1,2 et 3
sensorMes = ["SensorMes"+str(j) for j in range(1, 22)] # de 1 à 21
columnsNames = unitNames + timeCycles + operSets +sensorMes

# %% [markdown]
# # **Datasets loading**

# %%
def data_loading(x):
  train_path = myfolder + "train_"+ x +".txt"
  test_path = myfolder + "test_"+ x +".txt"
  rul_path = myfolder + "RUL_"+ x +".txt"
  train = pd.read_csv(train_path, delim_whitespace=True, names=columnsNames)
  test = pd.read_csv(test_path, delim_whitespace=True, names=columnsNames)
  rul = pd.read_csv(rul_path, delim_whitespace=True, names=["RUL_FD"])
  return train, test, rul

train_fd001, test_fd001, rul_fd001 = data_loading("FD001")
train_fd002, test_fd002, rul_fd002 = data_loading("FD002")
train_fd003, test_fd003, rul_fd003 = data_loading("FD003")
train_fd004, test_fd004, rul_fd004 = data_loading("FD004")

# %%
# Forcer l'affichage de toutes les colonnes
pd.set_option('display.max_columns', None)

train_fd004.head(3)
# Out:
#    UnitNumber  TimeInCycles  OperSet1  OperSet2  OperSet3  SensorMes1  \
# 0           1             1   42.0049    0.8400     100.0      445.00
# 1           1             2   20.0020    0.7002     100.0      491.19
# 2           1             3   42.0038    0.8409     100.0      445.00
#
#    SensorMes2  SensorMes3  SensorMes4  SensorMes5  SensorMes6  SensorMes7  \
# 0      549.68     1343.43     1112.93        3.91        5.70      137.36
# 1      606.07     1477.61     1237.50        9.35       13.61      332.10
# 2      548.95     1343.12     1117.05        3.91        5.69      138.18
#
#    SensorMes8  SensorMes9  SensorMes10  SensorMes11  SensorMes12  SensorMes13  \
# 0     2211.86     8311.32         1.01        41.69       129.78      2387.99
# 1     2323.66     8713.60         1.07        43.94       312.59      2387.73
# 2     2211.92     8306.69         1.01        41.66       129.62      2387.97
#
#    SensorMes14  SensorMes15  SensorMes16  SensorMes17  SensorMes18  \
# 0      8074.83       9.3335         0.02          330         2212
# 1      8046.13       9.1913         0.02          361         2324
# 2      8066.62       9.4007         0.02          329         2212
#
#    SensorMes19  SensorMes20  SensorMes21
# 0        100.0        10.62       6.3670
# 1        100.0        24.37      14.6552
# 2        100.0        10.48       6.4213

# %% [markdown]
# # **RUL column generation for train and test set**

# %%
def rul_train_generation(x):
  rul = pd.DataFrame(x.groupby('UnitNumber')['TimeInCycles'].max()).reset_index()
  rul.columns = ['UnitNumber', 'max']
  x = x.merge(rul, on=['UnitNumber'], how='left')
  x['RUL'] = x['max'] - x['TimeInCycles']
  x.drop('max', axis=1, inplace=True)
  return x

train_fd001 = rul_train_generation(train_fd001)
train_fd002 = rul_train_generation(train_fd002)
train_fd003 = rul_train_generation(train_fd003)
train_fd004 = rul_train_generation(train_fd004)

# %%
train_fd004.head(3)
# Out:
#    UnitNumber  TimeInCycles  OperSet1  OperSet2  OperSet3  SensorMes1  \
# 0           1             1   42.0049    0.8400     100.0      445.00
# 1           1             2   20.0020    0.7002     100.0      491.19
# 2           1             3   42.0038    0.8409     100.0      445.00
#
#    SensorMes2  SensorMes3  SensorMes4  SensorMes5  SensorMes6  SensorMes7  \
# 0      549.68     1343.43     1112.93        3.91        5.70      137.36
# 1      606.07     1477.61     1237.50        9.35       13.61      332.10
# 2      548.95     1343.12     1117.05        3.91        5.69      138.18
#
#    SensorMes8  SensorMes9  SensorMes10  SensorMes11  SensorMes12  SensorMes13  \
# 0     2211.86     8311.32         1.01        41.69       129.78      2387.99
# 1     2323.66     8713.60         1.07        43.94       312.59      2387.73
# 2     2211.92     8306.69         1.01        41.66       129.62      2387.97
#
#    SensorMes14  SensorMes15  SensorMes16  SensorMes17  SensorMes18  \
# 0      8074.83       9.3335         0.02          330         2212
# 1      8046.13       9.1913         0.02          361         2324
# 2      8066.62       9.4007         0.02          329         2212
#
#    SensorMes19  SensorMes20  SensorMes21  RUL
# 0        100.0        10.62       6.3670  320
# 1        100.0        24.37      14.6552  319
# 2        100.0        10.48       6.4213  318

# %%
def rul_test_generation(x, rul):

  rul["UnitNumber"] = rul.index + 1 # +1 pour que UnitNumber demarre de 1 au lieu de 0, car il s'agit du numero des moteur

  x = x.merge(rul, on=['UnitNumber'], how='left')

  max_cycle = pd.DataFrame(x.groupby('UnitNumber')['TimeInCycles'].max()).reset_index()
  max_cycle.columns = ['UnitNumber', 'max']
  x = x.merge(max_cycle, on=['UnitNumber'], how='left')
  x['RUL'] = x['RUL_FD'] + x['max'] - x['TimeInCycles']
  x.drop(['max', 'RUL_FD'], axis=1, inplace=True)

  return x

test_fd001 = rul_test_generation(test_fd001, rul_fd001)
test_fd002 = rul_test_generation(test_fd002, rul_fd002)
test_fd003 = rul_test_generation(test_fd003, rul_fd003)
test_fd004 = rul_test_generation(test_fd004, rul_fd004)

# %%
test_fd004.head(3)
# Out:
#    UnitNumber  TimeInCycles  OperSet1  OperSet2  OperSet3  SensorMes1  \
# 0           1             1   20.0072     0.700     100.0      491.19
# 1           1             2   24.9984     0.620      60.0      462.54
# 2           1             3   42.0000     0.842     100.0      445.00
#
#    SensorMes2  SensorMes3  SensorMes4  SensorMes5  SensorMes6  SensorMes7  \
# 0      606.67     1481.04     1227.81        9.35       13.60      332.52
# 1      536.22     1256.17     1031.48        7.05        9.00      174.46
# 2      549.23     1340.13     1105.88        3.91        5.69      137.34
#
#    SensorMes8  SensorMes9  SensorMes10  SensorMes11  SensorMes12  SensorMes13  \
# 0     2323.67     8704.98         1.07        43.83       313.03      2387.78
# 1     1915.21     7999.94         0.93        36.11       163.61      2028.09
# 2     2211.93     8305.38         1.01        41.52       129.98      2387.95
#
#    SensorMes14  SensorMes15  SensorMes16  SensorMes17  SensorMes18  \
# 0      8048.98       9.2229         0.02          362         2324
# 1      7863.46      10.8632         0.02          306         1915
# 2      8071.13       9.3960         0.02          328         2212
#
#    SensorMes19  SensorMes20  SensorMes21  RUL
# 0       100.00        24.31      14.7007  251
# 1        84.93        14.36       8.5748  250
# 2       100.00        10.39       6.4365  249

# %% [markdown]
# # **RANDOM SAMPLE SELECTION**

# %%
'''element_counts = test_fd002[test_fd002['UnitNumber']==1]
len(element_counts)'''
# Out:
# "element_counts = test_fd002[test_fd002['UnitNumber']==1]\nlen(element_counts)"

# %%
import random

def selection_aleatoire(df, sample_size, rand_state):
    unique_values = df["UnitNumber"].unique()
    selected_rows = []
    for value in unique_values:
        rows = df[df["UnitNumber"] == value]
        if len(rows) < sample_size : # si la taille de l'echantillon donnée est superieur au nombre total de ligne pour un moteur, reinitialiser la valeur
            sample_size = len(rows)
        random_sample = rows.sample(n=sample_size, random_state = rand_state)  # Sélectionne 50 lignes aléatoires
        selected_rows.append(random_sample)
    result = pd.concat(selected_rows)
    return result

# %% [markdown]
# # **Data normalization**

# %%
def normalised_df(train, test):

  from sklearn.preprocessing import MinMaxScaler

  # Instancier l'objet MinMaxScaler pour normaliser les données
  scaler = MinMaxScaler()

  # Normaliser train
  train_scaled = scaler.fit_transform(train)
  train_df = pd.DataFrame(train_scaled)

  # Normaliser test
  test_scaled = scaler.fit_transform(test)
  test_df = pd.DataFrame(test_scaled)


  train_df.columns = train.columns
  test_df.columns = test.columns
    
  return train_df, test_df

# %% [markdown]
# # **Data splitting**

# %%
def data_split(train, test):

  # data split
  X_train = train.drop('RUL', axis=1)
  Y_train = train['RUL']
  X_test = test.drop('RUL', axis=1)
  Y_test = test['RUL']
    
  return X_train, Y_train, X_test, Y_test

# %% [markdown]
# # **The KNN Regressor model**

# %%
import time

def my_knn_regressor(x, y):

    # Time tracking, Operation time (min)
    t = time.process_time()
    
    t = time.process_time()

    mse_test_list = []
    rmse_test_list = []
    mae_test_list = []
    mape_test_list = []
    
    for j in range(1, 11):
        train_selected = selection_aleatoire(x, 50, j)
        test_selected = selection_aleatoire(y, 25, j)

        normalized_train_df, normalized_test_df =  normalised_df(train_selected, test_selected)

        X_train, Y_train, X_test, Y_test = data_split(normalized_train_df, normalized_test_df)

        '''print("===============",j,"=====================")
        print('La taille de X_train est:', X_train.shape)
        print('La taille de Y_train est:', Y_train.shape)
        print('La taille de X_test est:', X_test.shape)
        print('La taille de Y_test est:', Y_test.shape)'''

        # Créer le modèle KNN Regressor
        model = KNeighborsRegressor()

        # Définir les paramètres à tester dans la recherche par grille
        '''param_grid = {
            'n_neighbors': np.arange(1, 150),  # Increase the range up to 500
            'weights': ['uniform', 'distance'],
            'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],  # Add 'algorithm' hyperparameter
            'leaf_size': np.arange(1, 60),  # Add 'leaf_size' hyperparameter
            'p': [1, 2],  # Add 'p' hyperparameter
            'metric': ['euclidean', 'manhattan', 'minkowski', 'chebyshev'],  # Add 'chebyshev' in 'metric'
            'metric_params': [None],  # Add 'metric_params' hyperparameter
            'n_jobs': [None, -1]  # Add 'n_jobs' hyperparameter
        }'''
        param_grid = {
          'n_neighbors': np.arange(1, 100),
          'weights': ['uniform', 'distance'],
          'metric': ['euclidean', 'manhattan', 'minkowski', 'chebyshev']
          }
        # Créer l'objet GridSearchCV
        grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

        # Effectuer la recherche par grille sur les données d'entraînement
        grid_search.fit(X_train, Y_train)

        print("\n***********************TOUR No ",j,"/10:************************")

        # Afficher les meilleurs paramètres trouvés
        print("Meilleurs paramètres trouvés :")
        print(grid_search.best_params_)

        '''#-------------Train---------------------
        # Prédire les valeurs en utilisant le modèle KNN Regressor pour les données Train
        y_pred_train = grid_search.predict(X_train)
        # Afficher l'erreur quadratique moyenne et le coefficient de détermination R2
        mse_train = mean_squared_error(Y_train, y_pred_train)
        rmse_train = np.sqrt(mse_train)
        print('Train:==========================================================')
        print('MSE : ',mse_train * 100,'%')
        print('RMSE : ',rmse_train * 100,'%')'''


        #-------------Test---------------------
        # Prédire les valeurs en utilisant le modèle KNN Regressor pour les données Test
        y_pred_test = grid_search.predict(X_test)
        # Afficher l'erreur quadratique moyenne et le coefficient de détermination R2
        mse_test = mean_squared_error(Y_test, y_pred_test)
        rmse_test = np.sqrt(mse_test)
        mae_test = mean_absolute_error(Y_test, y_pred_test)
        mape_test = np.mean(np.abs((Y_test - y_pred_test) / Y_test)) * 100

        print('\n=============================Test=============================')
        print('MSE : ',mse_test * 100,'%')
        print('RMSE : ',rmse_test * 100,'%')
        print('MAE : ',mae_test * 100,'%')
        print('MAPE : ',mape_test,'%')

        #score
        '''train_rmse_list.append(mse_train)'''
        mse_test_list.append(mse_test)
        rmse_test_list.append(rmse_test)
        mae_test_list.append(mae_test)
        mape_test_list.append(mape_test)
        
        
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print("time: " , (time.process_time()-t)/60,"min")
        print('')

    print("\n\n++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print("Total time: " , (time.process_time()-t)/60,"min")
                              
    print('All MSE: ',mse_test_list)
    print('\n\nmean MSE', np.mean(mse_test_list), " == ",np.mean(mse_test_list)*100,"%\n\n")
    
    print('All RMSE: ',rmse_test_list)
    print('\n\n******************************************************************************************')
    print('******************************************************************************************')
    print('***************** mean RMSE', np.mean(rmse_test_list), " ==> ",np.mean(rmse_test_list)*100,"% *****************")
    print('******************************************************************************************')
    print('******************************************************************************************\n\n')


    print('mean MAE : ', np.mean(mae_test_list) * 100,'%')
    print('mean MAPE : ', np.mean(mape_test_list),'%')

# %%
my_knn_regressor(train_fd001, test_fd001)
# Out:
# ***********************TOUR No  1 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 49, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.676992703989264 %
# RMSE :  16.36151797355387 %
# MAE :  12.356778074647618 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  41.545833333333334 min
#
#
# ***********************TOUR No  2 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 48, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  3.55232961312451 %
# RMSE :  18.847624818858502 %
# MAE :  14.665332811799193 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  87.25052083333334 min
#
#
# ***********************TOUR No  3 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 42, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  3.1305405126617067 %
# RMSE :  17.693333526110074 %
# MAE :  13.504529309754826 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  129.103125 min
#
#
# ***********************TOUR No  4 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 55, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  3.613938339549195 %
# RMSE :  19.01036122631339 %
# MAE :  14.728962699889921 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  170.69166666666666 min
#
#
# ***********************TOUR No  5 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 62, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.832863340699703 %
# RMSE :  16.831112086548835 %
# MAE :  12.826425266653757 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  205.31041666666667 min
#
#
# ***********************TOUR No  6 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 47, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  3.23896701377955 %
# RMSE :  17.997130365087514 %
# MAE :  13.854380387158818 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  233.61848958333334 min
#
#
# ***********************TOUR No  7 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 51, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.6540139361342585 %
# RMSE :  16.29114463791375 %
# MAE :  12.24837386897597 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  261.49609375 min
#
#
# ***********************TOUR No  8 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 50, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.8576911429760954 %
# RMSE :  16.904706868136152 %
# MAE :  12.870757765032739 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  289.26875 min
#
#
# ***********************TOUR No  9 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 62, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.053460332182578 %
# RMSE :  14.329899972374468 %
# MAE :  10.571620241602993 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  316.55755208333335 min
#
#
# ***********************TOUR No  10 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 49, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  3.3374152610543684 %
# RMSE :  18.268593982719 %
# MAE :  14.175263306123579 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  345.4791666666667 min
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Total time:  345.4791666666667 min
# All MSE:  [0.02676992703989264, 0.0355232961312451, 0.031305405126617065, 0.03613938339549195, 0.02832863340699703, 0.0323896701377955, 0.026540139361342585, 0.028576911429760956, 0.02053460332182578, 0.03337415261054368]
#
#
# mean MSE 0.029948212196151226  ==  2.9948212196151225 %
#
#
# All RMSE:  [0.1636151797355387, 0.18847624818858502, 0.17693333526110072, 0.19010361226313388, 0.16831112086548836, 0.17997130365087513, 0.1629114463791375, 0.16904706868136152, 0.14329899972374469, 0.18268593982719]
#
#
# ******************************************************************************************
# ******************************************************************************************
# ***************** mean RMSE 0.17253542545761555  ==>  17.253542545761555 % *****************
# ******************************************************************************************
# ******************************************************************************************
#
#
# mean MAE :  13.180242373163939 %
# mean MAPE :  inf %

# %%
my_knn_regressor(train_fd002, test_fd002)
# Out:
# ***********************TOUR No  1 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 44, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.5224440291827976 %
# RMSE :  12.338735871971641 %
# MAE :  9.742361415725673 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  73.65338541666667 min
#
#
# ***********************TOUR No  2 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 51, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.7073701109021413 %
# RMSE :  13.06663732909941 %
# MAE :  10.206801743231836 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  148.54609375 min
#
#
# ***********************TOUR No  3 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 42, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.7360520258529002 %
# RMSE :  13.175932702670048 %
# MAE :  10.285210578111597 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  221.79557291666666 min
#
#
# ***********************TOUR No  4 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 54, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.7058564930114608 %
# RMSE :  13.060844126669075 %
# MAE :  10.204025586530534 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  295.74114583333335 min
#
#
# ***********************TOUR No  5 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 46, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.1420183803468733 %
# RMSE :  14.63563589444228 %
# MAE :  11.381430102013592 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  370.07395833333334 min
#
#
# ***********************TOUR No  6 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 37, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.7027171653671185 %
# RMSE :  13.048820503659012 %
# MAE :  10.236493070840943 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  443.13359375 min
#
#
# ***********************TOUR No  7 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 40, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.6946668841931234 %
# RMSE :  13.017937179880395 %
# MAE :  10.15748153936479 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  517.7924479166667 min
#
#
# ***********************TOUR No  8 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 45, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.4857788858857006 %
# RMSE :  12.189252995510843 %
# MAE :  9.501501824764794 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  591.18125 min
#
#
# ***********************TOUR No  9 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 58, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.7497949605781407 %
# RMSE :  13.227981556451235 %
# MAE :  10.292201240206843 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  665.2390625 min
#
#
# ***********************TOUR No  10 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 38, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.6359076340410803 %
# RMSE :  12.790260490080257 %
# MAE :  10.014828279111816 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  739.24921875 min
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Total time:  739.24921875 min
# All MSE:  [0.015224440291827977, 0.017073701109021414, 0.017360520258529, 0.01705856493011461, 0.02142018380346873, 0.017027171653671184, 0.016946668841931235, 0.014857788858857007, 0.017497949605781406, 0.016359076340410804]
#
#
# mean MSE 0.017082606569361336  ==  1.7082606569361336 %
#
#
# All RMSE:  [0.12338735871971641, 0.1306663732909941, 0.13175932702670048, 0.13060844126669074, 0.1463563589444228, 0.13048820503659012, 0.13017937179880396, 0.12189252995510844, 0.13227981556451235, 0.12790260490080257]
#
#
# ******************************************************************************************
# ******************************************************************************************
# ***************** mean RMSE 0.1305520386504342  ==>  13.055203865043419 % *****************
# ******************************************************************************************
# ******************************************************************************************
#
#
# mean MAE :  10.202233537990242 %
# mean MAPE :  inf %

# %%
my_knn_regressor(train_fd003, test_fd003)
# Out:
# ***********************TOUR No  1 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 53, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.388593937570959 %
# RMSE :  15.455076633815048 %
# MAE :  11.62337464293709 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  16.2359375 min
#
#
# ***********************TOUR No  2 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 81, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.8294878536088572 %
# RMSE :  16.821081575240214 %
# MAE :  12.635001425060894 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  32.15625 min
#
#
# ***********************TOUR No  3 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 81, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.2069725794458717 %
# RMSE :  14.855882940592496 %
# MAE :  10.968376881562747 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  48.46640625 min
#
#
# ***********************TOUR No  4 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 87, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.090000750702791 %
# RMSE :  14.45683489116062 %
# MAE :  10.185940114969789 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  64.70911458333333 min
#
#
# ***********************TOUR No  5 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 99, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.3084345705085685 %
# RMSE :  15.193533395851569 %
# MAE :  11.198102428771794 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  81.17057291666667 min
#
#
# ***********************TOUR No  6 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 74, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.3433255838285727 %
# RMSE :  15.30792469222583 %
# MAE :  11.320647466284736 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  97.60182291666666 min
#
#
# ***********************TOUR No  7 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 83, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.0534501133905154 %
# RMSE :  14.329864316840252 %
# MAE :  10.577663536129531 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  114.09296875 min
#
#
# ***********************TOUR No  8 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 90, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.284599291010823 %
# RMSE :  15.114890972186412 %
# MAE :  10.699835414982026 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  130.52317708333334 min
#
#
# ***********************TOUR No  9 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 85, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.8564380300989929 %
# RMSE :  13.625116623717364 %
# MAE :  9.499971510223347 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  147.02395833333333 min
#
#
# ***********************TOUR No  10 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 66, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.171390787266984 %
# RMSE :  14.735639746095124 %
# MAE :  10.72380884702932 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  163.04375 min
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Total time:  163.04375 min
# All MSE:  [0.023885939375709587, 0.028294878536088572, 0.022069725794458716, 0.02090000750702791, 0.023084345705085687, 0.023433255838285726, 0.020534501133905154, 0.02284599291010823, 0.01856438030098993, 0.02171390787266984]
#
#
# mean MSE 0.02253269349743293  ==  2.253269349743293 %
#
#
# All RMSE:  [0.15455076633815049, 0.16821081575240213, 0.14855882940592496, 0.1445683489116062, 0.1519353339585157, 0.1530792469222583, 0.14329864316840252, 0.15114890972186412, 0.13625116623717365, 0.14735639746095125]
#
#
# ******************************************************************************************
# ******************************************************************************************
# ***************** mean RMSE 0.14989584578772494  ==>  14.989584578772494 % *****************
# ******************************************************************************************
# ******************************************************************************************
#
#
# mean MAE :  10.943272226795127 %
# mean MAPE :  inf %

# %%
my_knn_regressor(train_fd004, test_fd004)
# Out:
# ***********************TOUR No  1 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 37, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.9143134260478145 %
# RMSE :  13.835871588186322 %
# MAE :  10.04748911166759 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  68.8578125 min
#
#
# ***********************TOUR No  2 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 36, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.8015665376954364 %
# RMSE :  13.422244736613306 %
# MAE :  10.354756728414669 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  138.34114583333334 min
#
#
# ***********************TOUR No  3 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 39, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.9893635172778117 %
# RMSE :  14.104479846055337 %
# MAE :  10.27514284970276 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  207.37291666666667 min
#
#
# ***********************TOUR No  4 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 42, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.8842371740233577 %
# RMSE :  13.726751888277713 %
# MAE :  10.069182532322971 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  276.8286458333333 min
#
#
# ***********************TOUR No  5 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 46, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  2.355870892957684 %
# RMSE :  15.348846513525649 %
# MAE :  10.94849856578665 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  345.77057291666665 min
#
#
# ***********************TOUR No  6 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 34, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.7655911993101867 %
# RMSE :  13.287555077252499 %
# MAE :  9.800276849944481 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  414.4604166666667 min
#
#
# ***********************TOUR No  7 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 34, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.918214742544082 %
# RMSE :  13.849962969423716 %
# MAE :  10.066067262072927 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  484.37708333333336 min
#
#
# ***********************TOUR No  8 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 36, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.830382491276286 %
# RMSE :  13.529162913041908 %
# MAE :  9.921739969786927 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  553.1416666666667 min
#
#
# ***********************TOUR No  9 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 40, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.9357961127043748 %
# RMSE :  13.913289016995137 %
# MAE :  10.04788526074513 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  622.49453125 min
#
#
# ***********************TOUR No  10 /10:************************
# Meilleurs paramètres trouvés :
# {'metric': 'manhattan', 'n_neighbors': 33, 'weights': 'distance'}
#
# =============================Test=============================
# MSE :  1.9936548720004519 %
# RMSE :  14.119684387409132 %
# MAE :  10.35788095514643 %
# MAPE :  inf %
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  691.94609375 min
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Total time:  691.94609375 min
# All MSE:  [0.019143134260478145, 0.018015665376954364, 0.019893635172778118, 0.018842371740233576, 0.023558708929576844, 0.017655911993101868, 0.01918214742544082, 0.01830382491276286, 0.019357961127043747, 0.01993654872000452]
#
#
# mean MSE 0.019388990965837485  ==  1.9388990965837485 %
#
#
# All RMSE:  [0.13835871588186321, 0.13422244736613306, 0.14104479846055337, 0.13726751888277713, 0.1534884651352565, 0.132875550772525, 0.13849962969423715, 0.1352916291304191, 0.13913289016995137, 0.14119684387409132]
#
#
# ******************************************************************************************
# ******************************************************************************************
# ***************** mean RMSE 0.13913784893678074  ==>  13.913784893678075 % *****************
# ******************************************************************************************
# ******************************************************************************************
#
#
# mean MAE :  10.188892008559055 %
# mean MAPE :  inf %
