# %%
'''from google.colab import drive
drive.mount('/content/drive')'''
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')"

# %%
#!pip install catboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy.stats import pearsonr

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
myfolder = "../data/CMaps/"

# %% [markdown]
# # **Columns' names**

# %%
#Columns' names
'''
1)  unit number
2)	time, in cycles
3)	operational setting 1
4)	operational setting 2
5)	operational setting 3
6)	sensor measurement  1
7)	sensor measurement  2
...
26)	sensor measurement  21
'''
unitNames = ['UnitNumber']
timeCycles = ["TimeInCycles"]
operSets = ["OperSet"+str(i) for i in range(1,4)] # 1,2 et 3
sensorMes = ["SensorMes"+str(j) for j in range(1, 22)] # de 1 à 21
columnsNames = unitNames + timeCycles + operSets +sensorMes

# %% [markdown]
# # **Datasets loading**

# %%
def data_loading(x):
  train_path = myfolder + "train_"+ x +".txt"
  test_path = myfolder + "test_"+ x +".txt"
  rul_path = myfolder + "RUL_"+ x +".txt"
  train = pd.read_csv(train_path, delim_whitespace=True, names=columnsNames)
  test = pd.read_csv(test_path, delim_whitespace=True, names=columnsNames)
  rul = pd.read_csv(rul_path, delim_whitespace=True, names=["RUL_FD"])
  return train, test, rul

train_fd001, test_fd001, rul_fd001 = data_loading("FD001")
train_fd002, test_fd002, rul_fd002 = data_loading("FD002")
train_fd003, test_fd003, rul_fd003 = data_loading("FD003")
train_fd004, test_fd004, rul_fd004 = data_loading("FD004")

# %%
# Forcer l'affichage de toutes les colonnes
pd.set_option('display.max_columns', None)

train_fd004.head(3)
# Out:
#    UnitNumber  TimeInCycles  OperSet1  OperSet2  OperSet3  SensorMes1  \
# 0           1             1   42.0049    0.8400     100.0      445.00
# 1           1             2   20.0020    0.7002     100.0      491.19
# 2           1             3   42.0038    0.8409     100.0      445.00
#
#    SensorMes2  SensorMes3  SensorMes4  SensorMes5  SensorMes6  SensorMes7  \
# 0      549.68     1343.43     1112.93        3.91        5.70      137.36
# 1      606.07     1477.61     1237.50        9.35       13.61      332.10
# 2      548.95     1343.12     1117.05        3.91        5.69      138.18
#
#    SensorMes8  SensorMes9  SensorMes10  SensorMes11  SensorMes12  SensorMes13  \
# 0     2211.86     8311.32         1.01        41.69       129.78      2387.99
# 1     2323.66     8713.60         1.07        43.94       312.59      2387.73
# 2     2211.92     8306.69         1.01        41.66       129.62      2387.97
#
#    SensorMes14  SensorMes15  SensorMes16  SensorMes17  SensorMes18  \
# 0      8074.83       9.3335         0.02          330         2212
# 1      8046.13       9.1913         0.02          361         2324
# 2      8066.62       9.4007         0.02          329         2212
#
#    SensorMes19  SensorMes20  SensorMes21
# 0        100.0        10.62       6.3670
# 1        100.0        24.37      14.6552
# 2        100.0        10.48       6.4213

# %% [markdown]
# # **RUL column generation for train and test set**

# %%
def rul_train_generation(x):
  rul = pd.DataFrame(x.groupby('UnitNumber')['TimeInCycles'].max()).reset_index()
  rul.columns = ['UnitNumber', 'max']
  x = x.merge(rul, on=['UnitNumber'], how='left')
  x['RUL'] = x['max'] - x['TimeInCycles']
  x.drop('max', axis=1, inplace=True)
  return x

train_fd001 = rul_train_generation(train_fd001)
train_fd002 = rul_train_generation(train_fd002)
train_fd003 = rul_train_generation(train_fd003)
train_fd004 = rul_train_generation(train_fd004)

# %%
train_fd004.head(3)
# Out:
#    UnitNumber  TimeInCycles  OperSet1  OperSet2  OperSet3  SensorMes1  \
# 0           1             1   42.0049    0.8400     100.0      445.00
# 1           1             2   20.0020    0.7002     100.0      491.19
# 2           1             3   42.0038    0.8409     100.0      445.00
#
#    SensorMes2  SensorMes3  SensorMes4  SensorMes5  SensorMes6  SensorMes7  \
# 0      549.68     1343.43     1112.93        3.91        5.70      137.36
# 1      606.07     1477.61     1237.50        9.35       13.61      332.10
# 2      548.95     1343.12     1117.05        3.91        5.69      138.18
#
#    SensorMes8  SensorMes9  SensorMes10  SensorMes11  SensorMes12  SensorMes13  \
# 0     2211.86     8311.32         1.01        41.69       129.78      2387.99
# 1     2323.66     8713.60         1.07        43.94       312.59      2387.73
# 2     2211.92     8306.69         1.01        41.66       129.62      2387.97
#
#    SensorMes14  SensorMes15  SensorMes16  SensorMes17  SensorMes18  \
# 0      8074.83       9.3335         0.02          330         2212
# 1      8046.13       9.1913         0.02          361         2324
# 2      8066.62       9.4007         0.02          329         2212
#
#    SensorMes19  SensorMes20  SensorMes21  RUL
# 0        100.0        10.62       6.3670  320
# 1        100.0        24.37      14.6552  319
# 2        100.0        10.48       6.4213  318

# %%
def rul_test_generation(x, rul):

  rul["UnitNumber"] = rul.index + 1 # +1 pour que UnitNumber demarre de 1 au lieu de 0, car il s'agit du numero des moteur

  x = x.merge(rul, on=['UnitNumber'], how='left')

  max_cycle = pd.DataFrame(x.groupby('UnitNumber')['TimeInCycles'].max()).reset_index()
  max_cycle.columns = ['UnitNumber', 'max']
  x = x.merge(max_cycle, on=['UnitNumber'], how='left')
  x['RUL'] = x['RUL_FD'] + x['max'] - x['TimeInCycles']
  x.drop(['max', 'RUL_FD'], axis=1, inplace=True)

  return x

test_fd001 = rul_test_generation(test_fd001, rul_fd001)
test_fd002 = rul_test_generation(test_fd002, rul_fd002)
test_fd003 = rul_test_generation(test_fd003, rul_fd003)
test_fd004 = rul_test_generation(test_fd004, rul_fd004)

# %%
test_fd004.head(3)
# Out:
#    UnitNumber  TimeInCycles  OperSet1  OperSet2  OperSet3  SensorMes1  \
# 0           1             1   20.0072     0.700     100.0      491.19
# 1           1             2   24.9984     0.620      60.0      462.54
# 2           1             3   42.0000     0.842     100.0      445.00
#
#    SensorMes2  SensorMes3  SensorMes4  SensorMes5  SensorMes6  SensorMes7  \
# 0      606.67     1481.04     1227.81        9.35       13.60      332.52
# 1      536.22     1256.17     1031.48        7.05        9.00      174.46
# 2      549.23     1340.13     1105.88        3.91        5.69      137.34
#
#    SensorMes8  SensorMes9  SensorMes10  SensorMes11  SensorMes12  SensorMes13  \
# 0     2323.67     8704.98         1.07        43.83       313.03      2387.78
# 1     1915.21     7999.94         0.93        36.11       163.61      2028.09
# 2     2211.93     8305.38         1.01        41.52       129.98      2387.95
#
#    SensorMes14  SensorMes15  SensorMes16  SensorMes17  SensorMes18  \
# 0      8048.98       9.2229         0.02          362         2324
# 1      7863.46      10.8632         0.02          306         1915
# 2      8071.13       9.3960         0.02          328         2212
#
#    SensorMes19  SensorMes20  SensorMes21  RUL
# 0       100.00        24.31      14.7007  251
# 1        84.93        14.36       8.5748  250
# 2       100.00        10.39       6.4365  249

# %% [markdown]
# # **RANDOM SAMPLE SELECTION**

# %%
'''element_counts = test_fd002[test_fd002['UnitNumber']==1]
len(element_counts)'''
# Out:
# "element_counts = test_fd002[test_fd002['UnitNumber']==1]\nlen(element_counts)"

# %%
import random

def selection_aleatoire(df, sample_size, rand_state):
    unique_values = df["UnitNumber"].unique()
    selected_rows = []
    for value in unique_values:
        rows = df[df["UnitNumber"] == value]
        if len(rows) < sample_size : # si la taille de l'echantillon donnée est superieur au nombre total de ligne pour un moteur, reinitialiser la valeur
            sample_size = len(rows)
        random_sample = rows.sample(n=sample_size, random_state = rand_state)  # Sélectionne 50 lignes aléatoires
        selected_rows.append(random_sample)
    result = pd.concat(selected_rows)
    return result

# %% [markdown]
# # **Data normalization**

# %%
def normalised_df(train, test):

  from sklearn.preprocessing import MinMaxScaler

  # Instancier l'objet MinMaxScaler pour normaliser les données
  scaler = MinMaxScaler()

  # Normaliser train
  train_scaled = scaler.fit_transform(train)
  train_df = pd.DataFrame(train_scaled)

  # Normaliser test
  test_scaled = scaler.fit_transform(test)
  test_df = pd.DataFrame(test_scaled)


  train_df.columns = train.columns
  test_df.columns = test.columns
    
  return train_df, test_df

# %% [markdown]
# # **Data splitting**

# %%
def data_split(train, test):

  # data split
  X_train = train.drop('RUL', axis=1)
  Y_train = train['RUL']
  X_test = test.drop('RUL', axis=1)
  Y_test = test['RUL']
    
  return X_train, Y_train, X_test, Y_test

# %% [markdown]
# # calcul de S-score

# %%
#calcul de S-score
def compute_s_score(rul_true, rul_pred):
    diff = rul_pred - rul_true
    return np.sum(np.where(diff < 0, np.exp(-diff/13)-1, np.exp(diff/10)-1))

# %% [markdown]
# # **The XGB Regressor model**

# %%
import time

def my_XGB_Regressor(x, y):

    # Time tracking, Operation time (min)
    t = time.process_time()


    mse_test_list = []
    rmse_test_list = []
    mae_test_list = []
    mape_test_list = []
    s_score_list = []
    
    
    for j in range(1, 11):
        train_selected = selection_aleatoire(x, 50, j)
        test_selected = selection_aleatoire(y, 25, j)

        normalized_train_df, normalized_test_df =  normalised_df(train_selected, test_selected)

        X_train, Y_train, X_test, Y_test = data_split(normalized_train_df, normalized_test_df)

        # Créer le modèle XGBoost Regressor
        model = XGBRegressor()

        # Définir les paramètres à tester dans la recherche par grille
        '''param_grid = {
            'n_estimators': [100, 500, 1000],
            'max_depth': [3, 5, 7],
            'learning_rate': [0.01, 0.1, 0.3], #np.logspace(-3,-1,10)
            'subsample': [0.5, 0.7, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            }'''
        param_grid = {
            'n_estimators': [100],
            'max_depth': [3],
            'learning_rate': [0.01], #np.logspace(-3,-1,10)
            'subsample': [0.5],
            'colsample_bytree': [0.5],
            }

        # Créer l'objet GridSearchCV
        grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

        # Effectuer la recherche par grille sur les données d'entraînement
        grid_search.fit(X_train, Y_train)

        # Afficher les meilleurs paramètres trouvés
        print("Meilleurs paramètres trouvés :")
        print(grid_search.best_params_)
        
        # Créer l'objet GridSearchCV
        grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

        # Effectuer la recherche par grille sur les données d'entraînement
        grid_search.fit(X_train, Y_train)

        print("\n***********************TOUR No ",j,"/10:************************")

        # Afficher les meilleurs paramètres trouvés
        print("Meilleurs paramètres trouvés :")
        print(grid_search.best_params_)

        '''#-------------Train---------------------
        # Prédire les valeurs en utilisant le modèle KNN Regressor pour les données Train
        y_pred_train = grid_search.predict(X_train)
        # Afficher l'erreur quadratique moyenne et le coefficient de détermination R2
        mse_train = mean_squared_error(Y_train, y_pred_train)
        rmse_train = np.sqrt(mse_train)
        print('Train:==========================================================')
        print('MSE : ',mse_train * 100,'%')
        print('RMSE : ',rmse_train * 100,'%')'''

        #-------------Test---------------------
        # Prédire les valeurs en utilisant le modèle KNN Regressor pour les données Test
        y_pred_test = grid_search.predict(X_test)
        # Afficher l'erreur quadratique moyenne et le coefficient de détermination R2
        mse_test = mean_squared_error(Y_test, y_pred_test)
        rmse_test = np.sqrt(mse_test)
        mae_test = mean_absolute_error(Y_test, y_pred_test)
        mape_test = np.mean(np.abs((Y_test - y_pred_test) / Y_test)) * 100
        s_score = compute_s_score(Y_test, y_pred_test)

        print('\n=============================Test=============================')
        print('MSE : ',mse_test * 100,'%')
        print('RMSE : ',rmse_test * 100,'%')
        print('MAE : ',mae_test * 100,'%')
        print('MAPE : ',mape_test,'%')
        print("S-score: ", s_score)

        #score
        '''train_rmse_list.append(mse_train)'''
        mse_test_list.append(mse_test)
        rmse_test_list.append(rmse_test)
        mae_test_list.append(mae_test)
        mape_test_list.append(mape_test)
        s_score_list.append(s_score)
        
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print("time: " , (time.process_time()-t)/60,"min")
        print('')
        
        
        
    print("\n\n++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    print("Total time: " , (time.process_time()-t)/60,"min")
    
    print('All S-Score: ',s_score_list)
    print('\n mean S-Score', np.mean(s_score_list),'\n')
    
    print('All MSE: ',mse_test_list)
    print('\n\nmean MSE', np.mean(mse_test_list), " == ",np.mean(mse_test_list)*100,"%\n\n")
    
    print('All RMSE: ',rmse_test_list)
    print('\n\n******************************************************************************************')
    print('******************************************************************************************')
    print('***************** mean RMSE', np.mean(rmse_test_list), " ==> ",np.mean(rmse_test_list)*100,"% *****************")
    print('******************************************************************************************')
    print('******************************************************************************************\n\n')


    print('mean MAE : ', np.mean(mae_test_list) * 100,'%')
    print('mean MAPE : ', np.mean(mape_test_list),'%')

# %%
my_XGB_Regressor(train_fd001, test_fd001)
# Out:
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  1 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.6509720874297127 %
# RMSE :  12.84901586671023 %
# MAE :  9.716439102811316 %
# MAPE :  inf %
# S-score:  20.84239273575949
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.16119791666666666 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  2 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  2.0003033011791462 %
# RMSE :  14.143207914681685 %
# MAE :  10.634170137038542 %
# MAPE :  inf %
# S-score:  22.158004570227654
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.32317708333333334 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  3 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.9769101597497063 %
# RMSE :  14.060263723521357 %
# MAE :  10.570688146994517 %
# MAPE :  inf %
# S-score:  22.312394786483868
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.48541666666666666 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  4 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.8038397394279964 %
# RMSE :  13.430710105679433 %
# MAE :  9.949031342542533 %
# MAPE :  inf %
# S-score:  20.777672492244278
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.6484375 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  5 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.7069538775020283 %
# RMSE :  13.065044498592526 %
# MAE :  9.796365026721245 %
# MAPE :  inf %
# S-score:  20.739495542538958
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.81640625 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  6 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.786319003902367 %
# RMSE :  13.365324552371959 %
# MAE :  9.892147762326545 %
# MAPE :  inf %
# S-score:  20.904711717976173
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.98359375 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  7 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.543802178897165 %
# RMSE :  12.424983617281613 %
# MAE :  9.469745709693791 %
# MAPE :  inf %
# S-score:  20.602713373449085
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.1359375 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  8 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.6925965702117396 %
# RMSE :  13.009982975437515 %
# MAE :  9.806654645375614 %
# MAPE :  inf %
# S-score:  20.85812952537058
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.296875 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  9 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.620047657602722 %
# RMSE :  12.728109276725755 %
# MAE :  9.720891693248982 %
# MAPE :  inf %
# S-score:  21.15552768020193
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.465625 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  10 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.9297823864635462 %
# RMSE :  13.891660759115688 %
# MAE :  10.402296900429283 %
# MAPE :  inf %
# S-score:  21.57919995465436
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.6315104166666667 min
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Total time:  1.6315104166666667 min
# All S-Score:  [20.84239273575949, 22.158004570227654, 22.312394786483868, 20.777672492244278, 20.739495542538958, 20.904711717976173, 20.602713373449085, 20.85812952537058, 21.15552768020193, 21.57919995465436]
#
#  mean S-Score 21.193024237890636
#
# All MSE:  [0.016509720874297126, 0.020003033011791464, 0.019769101597497063, 0.018038397394279964, 0.017069538775020283, 0.01786319003902367, 0.01543802178897165, 0.016925965702117397, 0.01620047657602722, 0.019297823864635463]
#
#
# mean MSE 0.01771152696236613  ==  1.7711526962366129 %
#
#
# All RMSE:  [0.1284901586671023, 0.14143207914681685, 0.14060263723521357, 0.13430710105679433, 0.13065044498592526, 0.1336532455237196, 0.12424983617281614, 0.13009982975437515, 0.12728109276725755, 0.13891660759115687]
#
#
# ******************************************************************************************
# ******************************************************************************************
# ***************** mean RMSE 0.13296830329011775  ==>  13.296830329011774 % *****************
# ******************************************************************************************
# ******************************************************************************************
#
#
# mean MAE :  9.995843046718237 %
# mean MAPE :  inf %

# %%
my_XGB_Regressor(train_fd002, test_fd002)
# Out:
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  1 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.6832058862070656 %
# RMSE :  12.973842477103942 %
# MAE :  10.433505475702999 %
# MAPE :  inf %
# S-score:  51.567231620623055
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.3684895833333333 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  2 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.844497336664852 %
# RMSE :  13.58122725185339 %
# MAE :  10.738228623444181 %
# MAPE :  inf %
# S-score:  51.77718339225218
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.7447916666666666 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  3 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.8859472257049579 %
# RMSE :  13.732979377050553 %
# MAE :  10.865432705268002 %
# MAPE :  inf %
# S-score:  52.48893706153518
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.11328125 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  4 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.9162815512896811 %
# RMSE :  13.842982161693632 %
# MAE :  10.910975071425305 %
# MAPE :  inf %
# S-score:  52.349315426673996
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.4778645833333333 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  5 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  2.4100649737092903 %
# RMSE :  15.52438396107649 %
# MAE :  12.16845878528122 %
# MAPE :  inf %
# S-score:  57.005850579348355
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.8513020833333333 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  6 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.8707440275938503 %
# RMSE :  13.677514494943335 %
# MAE :  10.771618266506428 %
# MAPE :  inf %
# S-score:  52.23661482412117
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  2.226302083333333 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  7 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.8591795844793246 %
# RMSE :  13.63517357601041 %
# MAE :  10.90988132964837 %
# MAPE :  inf %
# S-score:  53.38506198345574
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  2.6028645833333335 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  8 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.674254126759591 %
# RMSE :  12.939297224963925 %
# MAE :  10.281298574404858 %
# MAPE :  inf %
# S-score:  50.59658165014618
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  2.965625 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  9 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.8654652495462603 %
# RMSE :  13.658203577140956 %
# MAE :  10.789189054845473 %
# MAPE :  inf %
# S-score:  51.81704790688654
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  3.335677083333333 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  10 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.678371932163605 %
# RMSE :  12.955199466482965 %
# MAE :  10.287775705483188 %
# MAPE :  inf %
# S-score:  49.87577954986644
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  3.6953125 min
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Total time:  3.6953125 min
# All S-Score:  [51.567231620623055, 51.77718339225218, 52.48893706153518, 52.349315426673996, 57.005850579348355, 52.23661482412117, 53.38506198345574, 50.59658165014618, 51.81704790688654, 49.87577954986644]
#
#  mean S-Score 52.30996039949089
#
# All MSE:  [0.016832058862070655, 0.01844497336664852, 0.018859472257049578, 0.01916281551289681, 0.024100649737092902, 0.018707440275938503, 0.018591795844793247, 0.01674254126759591, 0.018654652495462602, 0.01678371932163605]
#
#
# mean MSE 0.01868801189411848  ==  1.8688011894118481 %
#
#
# All RMSE:  [0.12973842477103942, 0.1358122725185339, 0.13732979377050553, 0.13842982161693632, 0.1552438396107649, 0.13677514494943335, 0.1363517357601041, 0.12939297224963925, 0.13658203577140957, 0.12955199466482964]
#
#
# ******************************************************************************************
# ******************************************************************************************
# ***************** mean RMSE 0.13652080356831958  ==>  13.652080356831958 % *****************
# ******************************************************************************************
# ******************************************************************************************
#
#
# mean MAE :  10.815636359201001 %
# mean MAPE :  inf %

# %%
my_XGB_Regressor(train_fd003, test_fd003)
# Out:
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  1 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.3632117645283306 %
# RMSE :  11.675665996114871 %
# MAE :  8.690582285857504 %
# MAPE :  inf %
# S-score:  19.518917568201033
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.16979166666666667 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  2 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.6309519603334026 %
# RMSE :  12.770872955023094 %
# MAE :  9.022868444100512 %
# MAPE :  inf %
# S-score:  19.5159704923296
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.3375 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  3 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.4882398200933995 %
# RMSE :  12.199343507309726 %
# MAE :  8.868760182966831 %
# MAPE :  inf %
# S-score:  19.778373733349273
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.5091145833333334 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  4 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.6344782358815952 %
# RMSE :  12.784671430590599 %
# MAE :  9.453800370378026 %
# MAPE :  inf %
# S-score:  21.46617285087514
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.67890625 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  5 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.546322953469662 %
# RMSE :  12.435123455236228 %
# MAE :  8.986824457463777 %
# MAPE :  inf %
# S-score:  19.862287021095508
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.84296875 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  6 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.4366291730213356 %
# RMSE :  11.985946658572011 %
# MAE :  8.811784090265986 %
# MAPE :  inf %
# S-score:  19.70691029942674
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.0041666666666667 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  7 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.4633717840480331 %
# RMSE :  12.096990468906029 %
# MAE :  8.887743058563824 %
# MAPE :  inf %
# S-score:  20.16962690181242
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.1755208333333333 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  8 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.5103597844947838 %
# RMSE :  12.289669582599785 %
# MAE :  8.993074172545281 %
# MAPE :  inf %
# S-score:  20.444439344951668
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.353125 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  9 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.4883579907732973 %
# RMSE :  12.199827829823244 %
# MAE :  8.907264319374205 %
# MAPE :  inf %
# S-score:  20.19283842028366
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.5203125 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  10 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.3951658333617933 %
# RMSE :  11.811713818755488 %
# MAE :  8.679757360971928 %
# MAPE :  inf %
# S-score:  19.532102975160882
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.6841145833333333 min
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Total time:  1.6841145833333333 min
# All S-Score:  [19.518917568201033, 19.5159704923296, 19.778373733349273, 21.46617285087514, 19.862287021095508, 19.70691029942674, 20.16962690181242, 20.444439344951668, 20.19283842028366, 19.532102975160882]
#
#  mean S-Score 20.018763960748593
#
# All MSE:  [0.013632117645283307, 0.016309519603334027, 0.014882398200933995, 0.01634478235881595, 0.01546322953469662, 0.014366291730213357, 0.01463371784048033, 0.015103597844947837, 0.014883579907732973, 0.013951658333617934]
#
#
# mean MSE 0.014957089300005635  ==  1.4957089300005635 %
#
#
# All RMSE:  [0.11675665996114871, 0.12770872955023094, 0.12199343507309725, 0.127846714305906, 0.12435123455236229, 0.11985946658572011, 0.12096990468906028, 0.12289669582599785, 0.12199827829823244, 0.11811713818755487]
#
#
# ******************************************************************************************
# ******************************************************************************************
# ***************** mean RMSE 0.12224982570293105  ==>  12.224982570293106 % *****************
# ******************************************************************************************
# ******************************************************************************************
#
#
# mean MAE :  8.930245874248788 %
# mean MAPE :  inf %

# %%
my_XGB_Regressor(train_fd004, test_fd004)
# Out:
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  1 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.6563143485035137 %
# RMSE :  12.869787676972427 %
# MAE :  10.021174179547645 %
# MAPE :  inf %
# S-score:  44.85876015023794
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.3692708333333333 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  2 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.7667530109280052 %
# RMSE :  13.291926161877388 %
# MAE :  10.612805658804913 %
# MAPE :  inf %
# S-score:  48.49971084658331
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  0.7372395833333333 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  3 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.7891943536771033 %
# RMSE :  13.376076979731778 %
# MAE :  10.405484653661116 %
# MAPE :  inf %
# S-score:  46.5199673222269
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.109375 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  4 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.7359498152834896 %
# RMSE :  13.175544828520335 %
# MAE :  10.138816253307766 %
# MAPE :  inf %
# S-score:  45.13570329495907
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.4760416666666667 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  5 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.903663906479624 %
# RMSE :  13.797332736727139 %
# MAE :  10.356323973342537 %
# MAPE :  inf %
# S-score:  44.92016148930888
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  1.84765625 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  6 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.7500389186750744 %
# RMSE :  13.228903653270269 %
# MAE :  10.3155839269851 %
# MAPE :  inf %
# S-score:  45.893583166191895
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  2.2161458333333335 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  7 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.713471078059122 %
# RMSE :  13.089962101011302 %
# MAE :  10.121173498593103 %
# MAPE :  inf %
# S-score:  45.19465178769724
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  2.5776041666666667 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  8 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.7430056129321274 %
# RMSE :  13.202293789081226 %
# MAE :  10.327543561091726 %
# MAPE :  inf %
# S-score:  46.66862363214079
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  2.9479166666666665 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  9 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.7923195209904157 %
# RMSE :  13.387753810816868 %
# MAE :  10.292797821357542 %
# MAPE :  inf %
# S-score:  46.01057454766806
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  3.3158854166666667 min
#
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# ***********************TOUR No  10 /10:************************
# Meilleurs paramètres trouvés :
# {'colsample_bytree': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
#
# =============================Test=============================
# MSE :  1.649576284198872 %
# RMSE :  12.843583161247768 %
# MAE :  9.962858485385159 %
# MAPE :  inf %
# S-score:  44.4921951614014
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# time:  3.695572916666667 min
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Total time:  3.695572916666667 min
# All S-Score:  [44.85876015023794, 48.49971084658331, 46.5199673222269, 45.13570329495907, 44.92016148930888, 45.893583166191895, 45.19465178769724, 46.66862363214079, 46.01057454766806, 44.4921951614014]
#
#  mean S-Score 45.81939313984155
#
# All MSE:  [0.016563143485035136, 0.01766753010928005, 0.017891943536771034, 0.017359498152834895, 0.01903663906479624, 0.017500389186750745, 0.01713471078059122, 0.017430056129321275, 0.017923195209904156, 0.01649576284198872]
#
#
# mean MSE 0.017500286849727348  ==  1.750028684972735 %
#
#
# All RMSE:  [0.12869787676972427, 0.13291926161877388, 0.13376076979731777, 0.13175544828520336, 0.1379733273672714, 0.1322890365327027, 0.13089962101011302, 0.13202293789081226, 0.1338775381081687, 0.12843583161247768]
#
#
# ******************************************************************************************
# ******************************************************************************************
# ***************** mean RMSE 0.1322631648992565  ==>  13.22631648992565 % *****************
# ******************************************************************************************
# ******************************************************************************************
#
#
# mean MAE :  10.25545620120766 %
# mean MAPE :  inf %
